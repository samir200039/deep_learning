# %%
""" Explore the effect of different learning rates and optimization algorithms (SGD, Adam, 
RMSprop) on the training performance of an MLP. Use a dataset like CIFAR-10 for 
image classification. Comment on the generalization gap between the training and test 
accuracy"""

# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import SGD, Adam, RMSprop

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize data
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Define MLP model
model = Sequential()
model.add(Flatten(input_shape=x_train.shape[1:]))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Define different learning rates
learning_rates = [0.1, 0.01, 0.001]

# Define different optimizers
optimizers = {
    'sgd': SGD(),
    'adam': Adam(),
    'rmsprop': RMSprop()
}

# Train model with different learning rates and optimizers
for lr in learning_rates:
    for name, optimizer in optimizers.items():
        print(f"Training with {name} optimizer and learning rate {lr}")
        optimizer.learning_rate = lr
        model.compile(loss='categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

        history = model.fit(x_train, y_train,
                            batch_size=32,
                            epochs=10,
                            validation_data=(x_test, y_test),
                            shuffle=True)
        

        
      

        # Calculate generalization gap
        train_accuracy = history.history['accuracy'][-1]
        test_accuracy = history.history['val_accuracy'][-1]
        generalization_gap = train_accuracy - test_accuracy
        print(f"Generalization gap: {generalization_gap}")
# Out:
# c:\Users\samir\anaconda3\envs\tf-gpu\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training with sgd optimizer and learning rate 0.1
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.2541 - loss: 2.0507 - val_accuracy: 0.3020 - val_loss: 1.9227
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.3765 - loss: 1.7330 - val_accuracy: 0.3921 - val_loss: 1.6989
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4144 - loss: 1.6321 - val_accuracy: 0.3768 - val_loss: 1.8199
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.4302 - loss: 1.5779 - val_accuracy: 0.4191 - val_loss: 1.5849
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.4481 - loss: 1.5359 - val_accuracy: 0.4261 - val_loss: 1.6077
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.4644 - loss: 1.4949 - val_accuracy: 0.4385 - val_loss: 1.5650
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.4707 - loss: 1.4792 - val_accuracy: 0.4213 - val_loss: 1.6467
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.4828 - loss: 1.4394 - val_accuracy: 0.4166 - val_loss: 1.6891
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4901 - loss: 1.4141 - val_accuracy: 0.4617 - val_loss: 1.5165
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.5017 - loss: 1.3930 - val_accuracy: 0.4734 - val_loss: 1.4792
# Generalization gap: 0.023860007524490356
# Training with adam optimizer and learning rate 0.1
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 21ms/step - accuracy: 0.1023 - loss: 77.4239 - val_accuracy: 0.1000 - val_loss: 2.3132
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 31s 20ms/step - accuracy: 0.0997 - loss: 2.3131 - val_accuracy: 0.1000 - val_loss: 2.3146
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 22ms/step - accuracy: 0.1001 - loss: 2.3151 - val_accuracy: 0.1000 - val_loss: 2.3115
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 20ms/step - accuracy: 0.1021 - loss: 2.3151 - val_accuracy: 0.1000 - val_loss: 2.3107
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.1021 - loss: 2.3146 - val_accuracy: 0.1000 - val_loss: 2.3080
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 22ms/step - accuracy: 0.0998 - loss: 2.3157 - val_accuracy: 0.1000 - val_loss: 2.3211
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.0994 - loss: 2.3171 - val_accuracy: 0.1000 - val_loss: 2.3198
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 20ms/step - accuracy: 0.0986 - loss: 2.3158 - val_accuracy: 0.1000 - val_loss: 2.3118
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.0969 - loss: 2.3165 - val_accuracy: 0.1000 - val_loss: 2.3124
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 37s 23ms/step - accuracy: 0.1008 - loss: 2.3157 - val_accuracy: 0.1000 - val_loss: 2.3095
# Generalization gap: 1.9997358322143555e-05
# Training with rmsprop optimizer and learning rate 0.1
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 0.1000 - loss: 2.3168 - val_accuracy: 0.1000 - val_loss: 2.3254
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.0981 - loss: 2.3166 - val_accuracy: 0.1000 - val_loss: 2.3187
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.1020 - loss: 2.3142 - val_accuracy: 0.1000 - val_loss: 2.3152
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.0980 - loss: 2.3170 - val_accuracy: 0.1000 - val_loss: 2.3264
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.0985 - loss: 2.3158 - val_accuracy: 0.1000 - val_loss: 2.3169
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.1024 - loss: 2.3155 - val_accuracy: 0.1000 - val_loss: 2.3130
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 0.1030 - loss: 2.3147 - val_accuracy: 0.1000 - val_loss: 2.3126
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 37s 23ms/step - accuracy: 0.0987 - loss: 2.3164 - val_accuracy: 0.1000 - val_loss: 2.3137
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 21ms/step - accuracy: 0.1008 - loss: 2.3153 - val_accuracy: 0.0998 - val_loss: 2.3363
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 20ms/step - accuracy: 0.0992 - loss: 2.3166 - val_accuracy: 0.1000 - val_loss: 2.3285
# Generalization gap: 0.00011999905109405518
# Training with sgd optimizer and learning rate 0.01
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.1032 - loss: 2.3163 - val_accuracy: 0.1000 - val_loss: 2.3049
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.0995 - loss: 2.3032 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.1019 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.0981 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.1012 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.0993 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.1010 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.1007 - loss: 2.3026 - val_accuracy: 0.0998 - val_loss: 2.3038
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0953 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.0976 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Generalization gap: -0.0023000016808509827
# Training with adam optimizer and learning rate 0.01
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 37s 23ms/step - accuracy: 0.1025 - loss: 2.3033 - val_accuracy: 0.1000 - val_loss: 2.3046
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.1002 - loss: 2.3041 - val_accuracy: 0.1000 - val_loss: 2.3048
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 0.1016 - loss: 2.3038 - val_accuracy: 0.1000 - val_loss: 2.3046
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 21ms/step - accuracy: 0.0981 - loss: 2.3041 - val_accuracy: 0.0998 - val_loss: 2.3049
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.0977 - loss: 2.3040 - val_accuracy: 0.1000 - val_loss: 2.3063
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 22ms/step - accuracy: 0.0954 - loss: 2.3044 - val_accuracy: 0.1000 - val_loss: 2.3047
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.1022 - loss: 2.3036 - val_accuracy: 0.1000 - val_loss: 2.3043
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 39s 25ms/step - accuracy: 0.0995 - loss: 2.3038 - val_accuracy: 0.1000 - val_loss: 2.3051
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 0.0985 - loss: 2.3040 - val_accuracy: 0.1000 - val_loss: 2.3057
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 22ms/step - accuracy: 0.0981 - loss: 2.3038 - val_accuracy: 0.1000 - val_loss: 2.3055
# Generalization gap: -0.002199999988079071
# Training with rmsprop optimizer and learning rate 0.01
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 22ms/step - accuracy: 0.1018 - loss: 2.3039 - val_accuracy: 0.1000 - val_loss: 2.3059
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.0984 - loss: 2.3041 - val_accuracy: 0.1000 - val_loss: 2.3049
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.1005 - loss: 2.3041 - val_accuracy: 0.1000 - val_loss: 2.3045
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 25s 16ms/step - accuracy: 0.1017 - loss: 2.3037 - val_accuracy: 0.1000 - val_loss: 2.3044
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - accuracy: 0.1022 - loss: 2.3036 - val_accuracy: 0.1000 - val_loss: 2.3042
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.0991 - loss: 2.3040 - val_accuracy: 0.1000 - val_loss: 2.3046
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.1050 - loss: 2.3037 - val_accuracy: 0.1000 - val_loss: 2.3056
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.0995 - loss: 2.3040 - val_accuracy: 0.1000 - val_loss: 2.3053
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.1004 - loss: 2.3040 - val_accuracy: 0.1000 - val_loss: 2.3043
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - accuracy: 0.1009 - loss: 2.3039 - val_accuracy: 0.1000 - val_loss: 2.3044
# Generalization gap: 4.000216722488403e-05
# Training with sgd optimizer and learning rate 0.001
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.0993 - loss: 2.3029 - val_accuracy: 0.1000 - val_loss: 2.3042
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.1018 - loss: 2.3029 - val_accuracy: 0.1000 - val_loss: 2.3041
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.1001 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3040
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.0994 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3040
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.0974 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3039
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.1000 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3039
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.1011 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3039
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.0988 - loss: 2.3025 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.1008 - loss: 2.3025 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0968 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Generalization gap: 1.9997358322143555e-05
# Training with adam optimizer and learning rate 0.001
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 25ms/step - accuracy: 0.0997 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 38s 25ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 38s 25ms/step - accuracy: 0.1034 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3039
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 31s 20ms/step - accuracy: 0.0958 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 0.1010 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 0.0961 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3039
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.0997 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 33s 21ms/step - accuracy: 0.1008 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 20ms/step - accuracy: 0.0992 - loss: 2.3026 - val_accuracy: 0.0998 - val_loss: 2.3039
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.0987 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Generalization gap: -0.0021400004625320435
# Training with rmsprop optimizer and learning rate 0.001
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 30s 18ms/step - accuracy: 0.0970 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.0962 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.1013 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3039
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - accuracy: 0.0984 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - accuracy: 0.0948 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3039
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.0998 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3039
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 32s 21ms/step - accuracy: 0.0999 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 22ms/step - accuracy: 0.0993 - loss: 2.3027 - val_accuracy: 0.0998 - val_loss: 2.3038
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 35s 23ms/step - accuracy: 0.0972 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3038
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 37s 23ms/step - accuracy: 0.0975 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3038
# Generalization gap: -0.002659998834133148
